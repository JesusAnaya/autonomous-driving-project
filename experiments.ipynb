# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("loss_acc_results.csv")

# %%
ax = sns.lineplot(data=df1["loss"])
plt.show()

# %%
df2 = pd.read_csv("loss_acc_validation.csv")
ax = sns.lineplot(data=df2["val_loss"])
plt.show()

# %%
import math
import numpy as np

degree = 252.610001

x = np.radians(degree) 
print(x)

z= x / 2
arctan_x = math.atan(z) * 2
print(arctan_x)

y = np.radians(degree) 
print(y / 2)
# Out:
# 4.408876240916168
# 2.2898550344328923
# 2.204438120458084
