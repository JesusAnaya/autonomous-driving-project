# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("logs/loss_acc_results.csv")
df1
# Out:
#           loss
# 0     0.154097
# 1     0.238916
# 2     0.240539
# 3     0.222275
# 4     0.223825
# ...        ...
# 6175  0.018080
# 6176  0.018079
# 6177  0.018077
# 6178  0.018075
# 6179  0.018072
#
# [6180 rows x 1 columns]

# %%
ax = sns.lineplot(data=df1["loss"])
plt.show()

# %%
df2 = pd.read_csv("logs/loss_acc_validation.csv")
df2
# Out:
#     val_loss
# 0   0.094132
# 1   0.052651
# 2   0.035804
# 3   0.032308
# 4   0.025642
# 5   0.025022
# 6   0.021737
# 7   0.020019
# 8   0.016867
# 9   0.023329
# 10  0.016371
# 11  0.019855
# 12  0.017205
# 13  0.014520
# 14  0.014963
# 15  0.014728
# 16  0.021647
# 17  0.013122
# 18  0.014673
# 19  0.019431
# 20  0.015018
# 21  0.012264
# 22  0.014175
# 23  0.011930
# 24  0.012904
# 25  0.017045
# 26  0.012345
# 27  0.018150
# 28  0.012052
# 29  0.013867
# 30  0.011658
# 31  0.014942
# 32  0.012045
# 33  0.011868
# 34  0.011859
# 35  0.010114
# 36  0.010479
# 37  0.011494
# 38  0.012873
# 39  0.013658
# 40  0.010003
# 41  0.011234
# 42  0.013349
# 43  0.012923
# 44  0.009669
# 45  0.009481
# 46  0.010076
# 47  0.010271
# 48  0.011187
# 49  0.010523
# 50  0.009665
# 51  0.009848
# 52  0.010216
# 53  0.010004
# 54  0.010294
# 55  0.009898
# 56  0.011041
# 57  0.011557
# 58  0.010588
# 59  0.009392

# %%
ax = sns.lineplot(data=df2["val_loss"])
plt.show()

# %%
import math
import numpy as np

degree = -152.610001

x = np.radians(degree) 
print(x)

z= x / 2
arctan_x = math.atan(z) * 2
print(arctan_x)

y = np.radians(degree) 
print(y / 2)
# Out:
# -2.663546988921839
# -1.853466510624913
# -1.3317734944609194
